# %%
import os
import sys
import pandas as pd
import numpy as np
import json
import re
import warnings
from scipy import stats
from dotenv import load_dotenv

import matplotlib.pyplot as plt

project_name = 'DataGenie'

warnings.filterwarnings('ignore', message='Could not infer format')

base_pth = os.getcwd().split(project_name)[0] + f'{project_name}/'

sys.path.append(base_pth)

from dxel.utils.llm_agent.agent import Agent
from dxel.utils.llm.gemini import Gemini
from dxel.utils.llm.groq import Groq
from dxel.datascience.agent import DataAnalystAgent

# %%
data_loc = base_pth+'notebook_io/data_agent/input/Titanic-Dataset.csv'

# %%
api_key = os.getenv('GOOGLE_API_KEY')
gemini_llm  = Gemini(api_key=api_key)

# %%
data_analyst_agent = DataAnalystAgent(gemini_llm,data_loc)

# %%
data_analyst_agent.think('tell me all columns')
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File ~/DataGenie/dxel/utils/llm/gemini.py:98, in Gemini.generate(self, user_prompt, system_prompt, max_tokens)
#      97 try:
# ---> 98     response = self._client.models.generate_content(
#      99         model=self.model_name,
#     100         contents=contents,
#     101         config=generation_config,
#     102         # Pass system instruction directly in the call if available
#     103     )
#     105     return response.text
#
# File ~/miniforge3/envs/datagenie/lib/python3.11/site-packages/google/genai/models.py:5076, in Models.generate_content(self, model, contents, config)
#    5075 i += 1
# -> 5076 response = self._generate_content(
#    5077     model=model, contents=contents, config=parsed_config
#    5078 )
#    5080 function_map = _extra_utils.get_function_map(parsed_config)
#
# File ~/miniforge3/envs/datagenie/lib/python3.11/site-packages/google/genai/models.py:3858, in Models._generate_content(self, model, contents, config)
#    3856 request_dict = _common.encode_unserializable_types(request_dict)
# -> 3858 response = self._api_client.request(
#    3859     'post', path, request_dict, http_options
#    3860 )
#    3862 if config is not None and getattr(
#    3863     config, 'should_return_http_response', None
#    3864 ):
#
# File ~/miniforge3/envs/datagenie/lib/python3.11/site-packages/google/genai/_api_client.py:1330, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1327 http_request = self._build_request(
#    1328     http_method, path, request_dict, http_options
#    1329 )
# -> 1330 response = self._request(http_request, http_options, stream=False)
#    1331 response_body = (
#    1332     response.response_stream[0] if response.response_stream else ''
#    1333 )
#
# File ~/miniforge3/envs/datagenie/lib/python3.11/site-packages/google/genai/_api_client.py:1166, in BaseApiClient._request(self, http_request, http_options, stream)
#    1164     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1166 return self._retry(self._request_once, http_request, stream)
#
# File ~/miniforge3/envs/datagenie/lib/python3.11/site-packages/tenacity/__init__.py:475, in Retrying.__call__(self, fn, *args, **kwargs)
#     474 while True:
# --> 475     do = self.iter(retry_state=retry_state)
#     476     if isinstance(do, DoAttempt):
#
# File ~/miniforge3/envs/datagenie/lib/python3.11/site-packages/tenacity/__init__.py:376, in BaseRetrying.iter(self, retry_state)
#     375 for action in self.iter_state.actions:
# --> 376     result = action(retry_state)
#     377 return result
#
# File ~/miniforge3/envs/datagenie/lib/python3.11/site-packages/tenacity/__init__.py:418, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     417 if self.reraise:
# --> 418     raise retry_exc.reraise()
#     419 raise retry_exc from fut.exception()
#
# File ~/miniforge3/envs/datagenie/lib/python3.11/site-packages/tenacity/__init__.py:185, in RetryError.reraise(self)
#     184 if self.last_attempt.failed:
# --> 185     raise self.last_attempt.result()
#     186 raise self
#
# File ~/miniforge3/envs/datagenie/lib/python3.11/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#
# File ~/miniforge3/envs/datagenie/lib/python3.11/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File ~/miniforge3/envs/datagenie/lib/python3.11/site-packages/tenacity/__init__.py:478, in Retrying.__call__(self, fn, *args, **kwargs)
#     477 try:
# --> 478     result = fn(*args, **kwargs)
#     479 except BaseException:  # noqa: B902
#
# File ~/miniforge3/envs/datagenie/lib/python3.11/site-packages/google/genai/_api_client.py:1143, in BaseApiClient._request_once(self, http_request, stream)
#    1136 response = self._httpx_client.request(
#    1137     method=http_request.method,
#    1138     url=http_request.url,
#    (...)   1141     timeout=http_request.timeout,
#    1142 )
# -> 1143 errors.APIError.raise_for_response(response)
#    1144 return HttpResponse(
#    1145     response.headers, response if stream else [response.text]
#    1146 )
#
# File ~/miniforge3/envs/datagenie/lib/python3.11/site-packages/google/genai/errors.py:106, in APIError.raise_for_response(cls, response)
#     104   response_json = response.body_segments[0].get('error', {})
# --> 106 cls.raise_error(response.status_code, response_json, response)
#
# File ~/miniforge3/envs/datagenie/lib/python3.11/site-packages/google/genai/errors.py:131, in APIError.raise_error(cls, status_code, response_json, response)
#     130 if 400 <= status_code < 500:
# --> 131   raise ClientError(status_code, response_json, response)
#     132 elif 500 <= status_code < 600:
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 1.707701989s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash', 'location': 'global'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '1s'}]}}
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 data_analyst_agent.think('tell me all columns')
#
# File ~/DataGenie/dxel/datascience/agent/orchestration_agent.py:80, in DataAnalystAgent.think(self, user_prompt, chatbot)
#      77         print("I could not understand your question")
#      79 if agent_choice == '1':
# ---> 80     response = self.summary_agent.think(user_prompt)
#      81     if chatbot:
#      82         return {"type":"text" , "data":response}
#
# File ~/DataGenie/dxel/utils/llm_agent/agent.py:15, in Agent.think(self, user_prompt)
#       9 def think(self,user_prompt):
#      10
#      11     # user_prompt = self.agent_config.user_prompt_template.format(
#      12     #         input_json=context_json_str
#      13     #     )
# ---> 15     output = self.llm_model.generate( user_prompt, self.agent_config['system_prompt'])
#      17     return output
#
# File ~/DataGenie/dxel/utils/llm/gemini.py:108, in Gemini.generate(self, user_prompt, system_prompt, max_tokens)
#     105     return response.text
#     107 except APIError as e:
# --> 108     raise Exception(f"Gemini API call failed: {e}") from e
#
# Exception: Gemini API call failed: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 1.707701989s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash', 'location': 'global'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '1s'}]}}

# %%
o = data_analyst_agent.think("give me distibution of age colum")
